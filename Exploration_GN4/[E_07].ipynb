# %% [markdown]
# # 7. 뉴스 요약봇 만들기

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
pip install summa
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting summa
#   Downloading summa-1.2.0.tar.gz (54 kB)
#      |████████████████████████████████| 54 kB 1.8 MB/s
# Requirement already satisfied: scipy>=0.19 in /usr/local/lib/python3.7/dist-packages (from summa) (1.4.1)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from scipy>=0.19->summa) (1.21.6)
# Building wheels for collected packages: summa
#   Building wheel for summa (setup.py) ... done
#   Created wheel for summa: filename=summa-1.2.0-py3-none-any.whl size=54412 sha256=6249632c8366176c3913b8d87987c6a872befcaac0379ad3785f10de1a336cab
#   Stored in directory: /root/.cache/pip/wheels/29/64/ac/7b443477588d365ef37ada30d456bdf5f07dc5be9f6324cb6e
# Successfully built summa
# Installing collected packages: summa
# Successfully installed summa-1.2.0

# %%
from importlib_metadata import version
import nltk
import tensorflow
import summa
import pandas as pd 
print(nltk.__version__)
print(tensorflow.__version__)
print(version('summa'))
# Out:
# 3.2.5
# 2.8.0
# 1.2.0

# %%
import nltk
nltk.download('stopwords')

import numpy as np
import pandas as pd
import os
import re
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
from bs4 import BeautifulSoup 
from tensorflow.keras.preprocessing.text import Tokenizer 
from tensorflow.keras.preprocessing.sequence import pad_sequences
import urllib.request
import warnings
warnings.filterwarnings("ignore", category=UserWarning, module='bs4')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# ## Step 1. 데이터 수집하기

# %%
import urllib.request
urllib.request.urlretrieve("https://raw.githubusercontent.com/sunnysai12345/News_Summary/master/news_summary_more.csv", filename="news_summary_more.csv")
data = pd.read_csv('news_summary_more.csv', encoding='iso-8859-1')

# %%
data.sample(10)

#data.head()는 위에서부터 sample 은 랜덤하게
# Out:
#                                                headlines  \
# 97906  My current girlfriend is not from the film ind...
# 2850   Photo that got me my debut filmÃ¢ÂÂs auditio...
# 64577  Samajwadi Party to contest 5 seats in Gujarat ...
# 25509  Putin summit 'even better' than NATO meeting: ...
# 88768  Delhi Daredevils players meet IndiaÃ¢ÂÂs dai...
# 34181  4 Pakistani soldiers killed near LoC in retali...
# 97371  Astronaut captures lava of erupting volcano fr...
# 82734  Man arrested for masturbating mid-air on B'lur...
# 76851  Naidu won VP election by highest victory margi...
# 8051   Rajinikanth starrer '2.0' earns Ã¢ÂÂ¹100 cr w...
#
#                                                     text
# 97906  Actor Sooraj Pancholi has revealed that he is ...
# 2850   Actor Kartik Aaryan took to social media to sh...
# 64577  Samajwadi Party (SP) President Akhilesh Yadav ...
# 25509  Following criticism over his summit with Russi...
# 88768  Mother Dairy recently organised an event with ...
# 34181  At least four Pakistani soldiers were killed a...
# 97371  French astronaut Thomas Pesquet shared a photo...
# 82734  A 31-year-old man has been arrested for mastur...
# 76851  Vice President-elect M Venkaiah Naidu won the ...
# 8051   Rajinikanth and Akshay Kumar starrer '2.0' rel...

# %%
print('전체 샘플수 :', (len(data)))
# Out:
# 전체 샘플수 : 98401

# %% [markdown]
# # Step 2. 데이터 전처리하기 (추상적 요약)
#
# 실습에서 사용된 전처리를 참고하여 각자 필요하다고 생각하는 전처리를 추가 사용하여 텍스트를 정규화 또는 정제해 보세요. 만약, 불용어 제거를 선택한다면 상대적으로 길이가 짧은 요약 데이터에 대해서도 불용어를 제거하는 것이 좋을지 고민해 보세요.

# %%
print('Text 열에서 중복을 배제한 유일한 샘플의 수 :', data['text'].nunique())
print('Summary 열에서 중복을 배제한 유일한 샘플의 수 :', data['headlines'].nunique())
# Out:
# Text 열에서 중복을 배제한 유일한 샘플의 수 : 98360
# Summary 열에서 중복을 배제한 유일한 샘플의 수 : 98280

# %%
##### text 중복만 제거해준다. 

# inplace=True 를 설정하면 DataFrame 타입 값을 return 하지 않고 data 내부를 직접적으로 바꿉니다
data.drop_duplicates(subset = ['text'], inplace=True)
print('전체 샘플수 :', (len(data)))
# Out:
# 전체 샘플수 : 98360

# %%
##### null 값이 있는지 확인

print(data.isnull().sum())
# Out:
# headlines    0
# text         0
# dtype: int64

# %%
data.dropna(axis=0, inplace=True)
print('전체 샘플수 :', (len(data)))
# Out:
# 전체 샘플수 : 98360

# %%
##### 텍스트 정규화

contractions = {"ain't": "is not", "aren't": "are not","can't": "cannot", "'cause": "because", "could've": "could have", "couldn't": "could not",
                           "didn't": "did not",  "doesn't": "does not", "don't": "do not", "hadn't": "had not", "hasn't": "has not", "haven't": "have not",
                           "he'd": "he would","he'll": "he will", "he's": "he is", "how'd": "how did", "how'd'y": "how do you", "how'll": "how will", "how's": "how is",
                           "I'd": "I would", "I'd've": "I would have", "I'll": "I will", "I'll've": "I will have","I'm": "I am", "I've": "I have", "i'd": "i would",
                           "i'd've": "i would have", "i'll": "i will",  "i'll've": "i will have","i'm": "i am", "i've": "i have", "isn't": "is not", "it'd": "it would",
                           "it'd've": "it would have", "it'll": "it will", "it'll've": "it will have","it's": "it is", "let's": "let us", "ma'am": "madam",
                           "mayn't": "may not", "might've": "might have","mightn't": "might not","mightn't've": "might not have", "must've": "must have",
                           "mustn't": "must not", "mustn't've": "must not have", "needn't": "need not", "needn't've": "need not have","o'clock": "of the clock",
                           "oughtn't": "ought not", "oughtn't've": "ought not have", "shan't": "shall not", "sha'n't": "shall not", "shan't've": "shall not have",
                           "she'd": "she would", "she'd've": "she would have", "she'll": "she will", "she'll've": "she will have", "she's": "she is",
                           "should've": "should have", "shouldn't": "should not", "shouldn't've": "should not have", "so've": "so have","so's": "so as",
                           "this's": "this is","that'd": "that would", "that'd've": "that would have", "that's": "that is", "there'd": "there would",
                           "there'd've": "there would have", "there's": "there is", "here's": "here is","they'd": "they would", "they'd've": "they would have",
                           "they'll": "they will", "they'll've": "they will have", "they're": "they are", "they've": "they have", "to've": "to have",
                           "wasn't": "was not", "we'd": "we would", "we'd've": "we would have", "we'll": "we will", "we'll've": "we will have", "we're": "we are",
                           "we've": "we have", "weren't": "were not", "what'll": "what will", "what'll've": "what will have", "what're": "what are",
                           "what's": "what is", "what've": "what have", "when's": "when is", "when've": "when have", "where'd": "where did", "where's": "where is",
                           "where've": "where have", "who'll": "who will", "who'll've": "who will have", "who's": "who is", "who've": "who have",
                           "why's": "why is", "why've": "why have", "will've": "will have", "won't": "will not", "won't've": "will not have",
                           "would've": "would have", "wouldn't": "would not", "wouldn't've": "would not have", "y'all": "you all",
                           "y'all'd": "you all would","y'all'd've": "you all would have","y'all're": "you all are","y'all've": "you all have",
                           "you'd": "you would", "you'd've": "you would have", "you'll": "you will", "you'll've": "you will have",
                           "you're": "you are", "you've": "you have"}

print("정규화 사전의 수: ", len(contractions))
# Out:
# 정규화 사전의 수:  120

# %%
##### 불용어

print('불용어 개수 :', len(stopwords.words('english') ))
print(stopwords.words('english'))
# Out:
# 불용어 개수 : 179
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
##### 데이터 전처리 함수

def preprocess_sentence(sentence, remove_stopwords=True):
    sentence = sentence.lower() # 텍스트 소문자화
    sentence = BeautifulSoup(sentence, "lxml").text # <br />, <a href = ...> 등의 html 태그 제거
    sentence = re.sub(r'\([^)]*\)', '', sentence) # 괄호로 닫힌 문자열 (...) 제거 Ex) my husband (and myself!) for => my husband for
    sentence = re.sub('"','', sentence) # 쌍따옴표 " 제거
    sentence = ' '.join([contractions[t] if t in contractions else t for t in sentence.split(" ")]) # 약어 정규화
    sentence = re.sub(r"'s\b","", sentence) # 소유격 제거. Ex) roland's -> roland
    sentence = re.sub("[^a-zA-Z]", " ", sentence) # 영어 외 문자(숫자, 특수문자 등) 공백으로 변환
    sentence = re.sub('[m]{2,}', 'mm', sentence) # m이 3개 이상이면 2개로 변경. Ex) ummmmmmm yeah -> umm yeah
    
    # 불용어 제거 (Text)
    if remove_stopwords:
        tokens = ' '.join(word for word in sentence.split() if not word in stopwords.words('english') if len(word) > 1)
    # 불용어 미제거 (Summary)
    else:
        tokens = ' '.join(word for word in sentence.split() if len(word) > 1)
    return tokens

# %%
clean_headlines = []
# 전체 Summary 데이터에 대한 전처리 : 5분 이상 시간이 걸릴 수 있습니다. 
for s in data['headlines']:
    clean_headlines.append(preprocess_sentence(s, False))

print("Headlines 전처리 후 결과: ", clean_headlines[:5])
# Out:
# Headlines 전처리 후 결과:  ['upgrad learner switches to career in ml al with salary hike', 'delhi techie wins free food from swiggy for one year on cred', 'new zealand end rohit sharma led india match winning streak', 'aegon life iterm insurance plan helps customers save tax', 'have known hirani for yrs what if metoo claims are not true sonam']

# %%
clean_text = []
# 전체 Text 데이터에 대한 전처리 : 10분 이상 시간이 걸릴 수 있습니다. 
for s in data['text']:
    clean_text.append(preprocess_sentence(s))

# 전처리 후 출력
print("Text 전처리 후 결과: ", clean_text[:5])
# Out:
# Text 전처리 후 결과:  ['saurav kant alumnus upgrad iiit pg program machine learning artificial intelligence sr systems engineer infosys almost years work experience program upgrad degree career support helped transition data scientist tech mahindra salary hike upgrad online power learning powered lakh careers', 'kunal shah credit card bill payment platform cred gave users chance win free food swiggy one year pranav kaushik delhi techie bagged reward spending cred coins users get one cred coin per rupee bill paid used avail rewards brands like ixigo bookmyshow ubereats cult fit', 'new zealand defeated india wickets fourth odi hamilton thursday win first match five match odi series india lost international match rohit sharma captaincy consecutive victories dating back march match witnessed india getting seventh lowest total odi cricket history', 'aegon life iterm insurance plan customers enjoy tax benefits premiums paid save taxes plan provides life cover age years also customers options insure critical illnesses disability accidental death benefit rider life cover age years', 'speaking sexual harassment allegations rajkumar hirani sonam kapoor said known hirani many years true metoo movement get derailed metoo movement always believe woman case need reserve judgment added hirani accused assistant worked sanju']

# %%
data['text'] = clean_text
data['headlines'] = clean_headlines

# 빈 값을 Null 값으로 변환
data.replace('', np.nan, inplace=True)

# %%
data.isnull().sum()
# Out:
# headlines    0
# text         0
# dtype: int64

# %%
data.dropna(axis=0, inplace=True)
print('전체 샘플수 :', (len(data)))
# Out:
# 전체 샘플수 : 98360

# %%
print('전체 샘플수 :', (len(data)))
# Out:
# 전체 샘플수 : 98360

# %%
# 길이 분포 출력
import matplotlib.pyplot as plt

text_len = [len(s.split()) for s in data['text']]
headlines_len = [len(s.split()) for s in data['headlines']]

print('텍스트의 최소 길이 : {}'.format(np.min(text_len)))
print('텍스트의 최대 길이 : {}'.format(np.max(text_len)))
print('텍스트의 평균 길이 : {}'.format(np.mean(text_len)))
print('요약의 최소 길이 : {}'.format(np.min(headlines_len)))
print('요약의 최대 길이 : {}'.format(np.max(headlines_len)))
print('요약의 평균 길이 : {}'.format(np.mean(headlines_len)))

plt.subplot(1,2,1)
plt.boxplot(text_len)
plt.title('Text')
plt.subplot(1,2,2)
plt.boxplot(headlines_len)
plt.title('Summary')
plt.tight_layout()
plt.show()

plt.title('Text')
plt.hist(text_len, bins = 40)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()

plt.title('Headlines')
plt.hist(headlines_len, bins = 40)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()
# Out:
# 텍스트의 최소 길이 : 1
# 텍스트의 최대 길이 : 60
# 텍스트의 평균 길이 : 35.09968483123221
# 요약의 최소 길이 : 1
# 요약의 최대 길이 : 16
# 요약의 평균 길이 : 9.299532330215534
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 8 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 8 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
# 요약 데이터에는 시작 토큰과 종료 토큰을 추가한다.
data['decoder_input'] = data['headlines'].apply(lambda x : 'sostoken '+ x)
data['decoder_target'] = data['headlines'].apply(lambda x : x + ' eostoken')
data.head()
# Out:
#                                            headlines  \
# 0  upgrad learner switches to career in ml al wit...
# 1  delhi techie wins free food from swiggy for on...
# 2  new zealand end rohit sharma led india match w...
# 3  aegon life iterm insurance plan helps customer...
# 4  have known hirani for yrs what if metoo claims...
#
#                                                 text  \
# 0  saurav kant alumnus upgrad iiit pg program mac...
# 1  kunal shah credit card bill payment platform c...
# 2  new zealand defeated india wickets fourth odi ...
# 3  aegon life iterm insurance plan customers enjo...
# 4  speaking sexual harassment allegations rajkuma...
#
#                                        decoder_input  \
# 0  sostoken upgrad learner switches to career in ...
# 1  sostoken delhi techie wins free food from swig...
# 2  sostoken new zealand end rohit sharma led indi...
# 3  sostoken aegon life iterm insurance plan helps...
# 4  sostoken have known hirani for yrs what if met...
#
#                                       decoder_target
# 0  upgrad learner switches to career in ml al wit...
# 1  delhi techie wins free food from swiggy for on...
# 2  new zealand end rohit sharma led india match w...
# 3  aegon life iterm insurance plan helps customer...
# 4  have known hirani for yrs what if metoo claims...

# %%
encoder_input = np.array(data['text']) # 인코더의 입력
decoder_input = np.array(data['decoder_input']) # 디코더의 입력
decoder_target = np.array(data['decoder_target']) # 디코더의 레이블

# %%
print(type(encoder_input[0]))
# Out:
# <class 'str'>

# %%
# 훈련 데이터와 테스트 데이터를 분리

indices = np.arange(encoder_input.shape[0])
np.random.shuffle(indices)

encoder_input = encoder_input[indices]
decoder_input = decoder_input[indices]
decoder_target = decoder_target[indices]

n_of_val = int(len(encoder_input)*0.2)
print('테스트 데이터의 수 :', n_of_val)

encoder_input_train = encoder_input[:-n_of_val]
decoder_input_train = decoder_input[:-n_of_val]
decoder_target_train = decoder_target[:-n_of_val]

encoder_input_test = encoder_input[-n_of_val:]
decoder_input_test = decoder_input[-n_of_val:]
decoder_target_test = decoder_target[-n_of_val:]

print('훈련 데이터의 개수 :', len(encoder_input_train))
print('훈련 레이블의 개수 :', len(decoder_input_train))
print('테스트 데이터의 개수 :', len(encoder_input_test))
print('테스트 레이블의 개수 :', len(decoder_input_test))
# Out:
# 테스트 데이터의 수 : 19672
# 훈련 데이터의 개수 : 78688
# 훈련 레이블의 개수 : 78688
# 테스트 데이터의 개수 : 19672
# 테스트 레이블의 개수 : 19672

# %%
# 단어 집합(vocabulary) 만들기 및 정수 인코딩

src_tokenizer = Tokenizer() # 토크나이저 정의
src_tokenizer.fit_on_texts(encoder_input_train) # 입력된 데이터로부터 단어 집합 생성

# %%
threshold = 7
total_cnt = len(src_tokenizer.word_index) # 단어의 수
rare_cnt = 0 # 등장 빈도수가 threshold보다 작은 단어의 개수를 카운트
total_freq = 0 # 훈련 데이터의 전체 단어 빈도수 총 합
rare_freq = 0 # 등장 빈도수가 threshold보다 작은 단어의 등장 빈도수의 총 합

# 단어와 빈도수의 쌍(pair)을 key와 value로 받는다.
for key, value in src_tokenizer.word_counts.items():
    total_freq = total_freq + value

    # 단어의 등장 빈도수가 threshold보다 작으면
    if(value < threshold):
        rare_cnt = rare_cnt + 1
        rare_freq = rare_freq + value

print('단어 집합(vocabulary)의 크기 :', total_cnt)
print('등장 빈도가 %s번 이하인 희귀 단어의 수: %s'%(threshold - 1, rare_cnt))
print('단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 %s'%(total_cnt - rare_cnt))
print("단어 집합에서 희귀 단어의 비율:", (rare_cnt / total_cnt)*100)
print("전체 등장 빈도에서 희귀 단어 등장 빈도 비율:", (rare_freq / total_freq)*100)
# Out:
# 단어 집합(vocabulary)의 크기 : 69678
# 등장 빈도가 6번 이하인 희귀 단어의 수: 47497
# 단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 22181
# 단어 집합에서 희귀 단어의 비율: 68.16642268721834
# 전체 등장 빈도에서 희귀 단어 등장 빈도 비율: 3.4918152377952643

# %%
src_vocab = 8000
src_tokenizer = Tokenizer(num_words=src_vocab) # 단어 집합의 크기를 8,000으로 제한
src_tokenizer.fit_on_texts(encoder_input_train) # 단어 집합 재생성

# %%
# 텍스트 시퀀스를 정수 시퀀스로 변환
encoder_input_train = src_tokenizer.texts_to_sequences(encoder_input_train) 
encoder_input_test = src_tokenizer.texts_to_sequences(encoder_input_test)

# %%
tar_tokenizer = Tokenizer()
tar_tokenizer.fit_on_texts(decoder_input_train)

# %%
threshold = 6
total_cnt = len(tar_tokenizer.word_index) # 단어의 수
rare_cnt = 0 # 등장 빈도수가 threshold보다 작은 단어의 개수를 카운트
total_freq = 0 # 훈련 데이터의 전체 단어 빈도수 총 합
rare_freq = 0 # 등장 빈도수가 threshold보다 작은 단어의 등장 빈도수의 총 합

# 단어와 빈도수의 쌍(pair)을 key와 value로 받는다.
for key, value in tar_tokenizer.word_counts.items():
    total_freq = total_freq + value

    # 단어의 등장 빈도수가 threshold보다 작으면
    if(value < threshold):
        rare_cnt = rare_cnt + 1
        rare_freq = rare_freq + value

print('단어 집합(vocabulary)의 크기 :', total_cnt)
print('등장 빈도가 %s번 이하인 희귀 단어의 수: %s'%(threshold - 1, rare_cnt))
print('단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 %s'%(total_cnt - rare_cnt))
print("단어 집합에서 희귀 단어의 비율:", (rare_cnt / total_cnt)*100)
print("전체 등장 빈도에서 희귀 단어 등장 빈도 비율:", (rare_freq / total_freq)*100)
# Out:
# 단어 집합(vocabulary)의 크기 : 30159
# 등장 빈도가 5번 이하인 희귀 단어의 수: 19734
# 단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 10425
# 단어 집합에서 희귀 단어의 비율: 65.43320401870089
# 전체 등장 빈도에서 희귀 단어 등장 빈도 비율: 4.657321583489338

# %%
tar_vocab = 2000
tar_tokenizer = Tokenizer(num_words=tar_vocab) 
tar_tokenizer.fit_on_texts(decoder_input_train)
tar_tokenizer.fit_on_texts(decoder_target_train)

# 텍스트 시퀀스를 정수 시퀀스로 변환
decoder_input_train = tar_tokenizer.texts_to_sequences(decoder_input_train) 
decoder_target_train = tar_tokenizer.texts_to_sequences(decoder_target_train)
decoder_input_test = tar_tokenizer.texts_to_sequences(decoder_input_test)
decoder_target_test = tar_tokenizer.texts_to_sequences(decoder_target_test)

# 잘 변환되었는지 확인
print('input')
print('input ',decoder_input_train[:5])
print('target')
print('decoder ',decoder_target_train[:5])
# Out:
# input
# input  [[1, 39, 26, 215, 5, 1293], [1, 1009, 17, 655, 5, 122, 71], [1, 267, 3, 231, 5], [1, 63, 10, 369, 5, 989, 663, 30], [1, 98, 69, 1333, 5, 298, 438, 990, 977]]
# target
# decoder  [[39, 26, 215, 5, 1293, 2], [1009, 17, 655, 5, 122, 71, 2], [267, 3, 231, 5, 2], [63, 10, 369, 5, 989, 663, 30, 2], [98, 69, 1333, 5, 298, 438, 990, 977, 2]]

# %%
drop_train = [index for index, sentence in enumerate(decoder_input_train) if len(sentence) == 1]
drop_test = [index for index, sentence in enumerate(decoder_input_test) if len(sentence) == 1]

print('삭제할 훈련 데이터의 개수 :', len(drop_train))
print('삭제할 테스트 데이터의 개수 :', len(drop_test))

encoder_input_train = [sentence for index, sentence in enumerate(encoder_input_train) if index not in drop_train]
decoder_input_train = [sentence for index, sentence in enumerate(decoder_input_train) if index not in drop_train]
decoder_target_train = [sentence for index, sentence in enumerate(decoder_target_train) if index not in drop_train]

encoder_input_test = [sentence for index, sentence in enumerate(encoder_input_test) if index not in drop_test]
decoder_input_test = [sentence for index, sentence in enumerate(decoder_input_test) if index not in drop_test]
decoder_target_test = [sentence for index, sentence in enumerate(decoder_target_test) if index not in drop_test]

print('훈련 데이터의 개수 :', len(encoder_input_train))
print('훈련 레이블의 개수 :', len(decoder_input_train))
print('테스트 데이터의 개수 :', len(encoder_input_test))
print('테스트 레이블의 개수 :', len(decoder_input_test))
# Out:
# 삭제할 훈련 데이터의 개수 : 13
# 삭제할 테스트 데이터의 개수 : 1
# 훈련 데이터의 개수 : 78675
# 훈련 레이블의 개수 : 78675
# 테스트 데이터의 개수 : 19671
# 테스트 레이블의 개수 : 19671

# %%
text_max_len = 60
summary_max_len = 16

# %%
encoder_input_train = pad_sequences(encoder_input_train, maxlen=text_max_len, padding='post')
encoder_input_test = pad_sequences(encoder_input_test, maxlen=text_max_len, padding='post')

decoder_input_train = pad_sequences(decoder_input_train, maxlen=summary_max_len, padding='post')
decoder_target_train = pad_sequences(decoder_target_train, maxlen=summary_max_len, padding='post')

decoder_input_test = pad_sequences(decoder_input_test, maxlen=summary_max_len, padding='post')
decoder_target_test = pad_sequences(decoder_target_test, maxlen=summary_max_len, padding='post')

# %% [markdown]
# ## Step 3. 어텐션 메커니즘 사용하기 (추상적 요약)
#
# 일반적인 seq2seq보다는 어텐션 메커니즘을 사용한 seq2seq를 사용하는 것이 더 나은 성능을 얻을 수 있어요. 실습 내용을 참고하여 어텐션 메커니즘을 사용한 seq2seq를 설계해 보세요.

# %%
from tensorflow.keras.layers import Input, LSTM, Embedding, Dense, Concatenate, TimeDistributed
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint


# 인코더 설계 시작
embedding_dim = 128
hidden_size = 256

# 인코더
encoder_inputs = Input(shape=(text_max_len,))

# 인코더의 임베딩 층
enc_emb = Embedding(src_vocab, embedding_dim)(encoder_inputs)

# 인코더의 LSTM 1
# encoder_lstm1 = LSTM(hidden_size, return_sequences=True, return_state=True ,dropout = 0.4, recurrent_dropout = 0.4)
encoder_lstm1 = LSTM(hidden_size, return_sequences=True, return_state=True ,dropout = 0.4)
encoder_output1, state_h1, state_c1 = encoder_lstm1(enc_emb)

# 인코더의 LSTM 2
# encoder_lstm2 = LSTM(hidden_size, return_sequences=True, return_state=True, dropout=0.4, recurrent_dropout=0.4)
encoder_lstm2 = LSTM(hidden_size, return_sequences=True, return_state=True, dropout=0.4)
encoder_output2, state_h2, state_c2 = encoder_lstm2(encoder_output1)

# 인코더의 LSTM 3
# encoder_lstm3 = LSTM(hidden_size, return_state=True, return_sequences=True, dropout=0.4, recurrent_dropout=0.4)
encoder_lstm3 = LSTM(hidden_size, return_state=True, return_sequences=True, dropout=0.4)
encoder_outputs, state_h, state_c= encoder_lstm3(encoder_output2)

# %%
# 디코더 설계
decoder_inputs = Input(shape=(None,))

# 디코더의 임베딩 층
dec_emb_layer = Embedding(tar_vocab, embedding_dim)
dec_emb = dec_emb_layer(decoder_inputs)

# 디코더의 LSTM
# decoder_lstm = LSTM(hidden_size, return_sequences=True, return_state=True, dropout=0.4, recurrent_dropout=0.2)
decoder_lstm = LSTM(hidden_size, return_sequences=True, return_state=True, dropout=0.4)
decoder_outputs, _, _ = decoder_lstm(dec_emb, initial_state=[state_h, state_c])

# %%
from tensorflow.keras.layers import AdditiveAttention

# 어텐션 층(어텐션 함수)
attn_layer = AdditiveAttention(name='attention_layer')

# 인코더와 디코더의 모든 time step의 hidden state를 어텐션 층에 전달하고 결과를 리턴
attn_out = attn_layer([decoder_outputs, encoder_outputs])


# 어텐션의 결과와 디코더의 hidden state들을 연결
decoder_concat_input = Concatenate(axis=-1, name='concat_layer')([decoder_outputs, attn_out])

# 디코더의 출력층
decoder_softmax_layer = Dense(tar_vocab, activation='softmax')
decoder_softmax_outputs = decoder_softmax_layer(decoder_concat_input)

# 모델 정의
model = Model([encoder_inputs, decoder_inputs], decoder_softmax_outputs)
model.summary()
# Out:
# Model: "model_9"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_16 (InputLayer)          [(None, 60)]         0           []
#
#  embedding_6 (Embedding)        (None, 60, 128)      1024000     ['input_16[0][0]']
#
#  lstm_12 (LSTM)                 [(None, 60, 256),    394240      ['embedding_6[0][0]']
#                                  (None, 256),
#                                  (None, 256)]
#
#  input_17 (InputLayer)          [(None, None)]       0           []
#
#  lstm_13 (LSTM)                 [(None, 60, 256),    525312      ['lstm_12[0][0]']
#                                  (None, 256),
#                                  (None, 256)]
#
#  embedding_7 (Embedding)        (None, None, 128)    256000      ['input_17[0][0]']
#
#  lstm_14 (LSTM)                 [(None, 60, 256),    525312      ['lstm_13[0][0]']
#                                  (None, 256),
#                                  (None, 256)]
#
#  lstm_15 (LSTM)                 [(None, None, 256),  394240      ['embedding_7[0][0]',
#                                  (None, 256),                     'lstm_14[0][1]',
#                                  (None, 256)]                     'lstm_14[0][2]']
#
#  attention_layer (AdditiveAtten  (None, None, 256)   256         ['lstm_15[0][0]',
#  tion)                                                            'lstm_14[0][0]']
#
#  concat_layer (Concatenate)     (None, None, 512)    0           ['lstm_15[0][0]',
#                                                                   'attention_layer[0][0]']
#
#  dense_3 (Dense)                (None, None, 2000)   1026000     ['concat_layer[0][0]']
#
# ==================================================================================================
# Total params: 4,145,360
# Trainable params: 4,145,360
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy')
es = EarlyStopping(monitor='val_loss', patience=2, verbose=1)
history = model.fit(x=[encoder_input_train, decoder_input_train], y=decoder_target_train, \
          validation_data=([encoder_input_test, decoder_input_test], decoder_target_test), \
          batch_size=256, callbacks=[es], epochs=50)
# Out:
# Epoch 1/50
# 308/308 [==============================] - 32s 85ms/step - loss: 2.9411 - val_loss: 2.7024
# Epoch 2/50
# 308/308 [==============================] - 25s 80ms/step - loss: 2.5747 - val_loss: 2.4817
# Epoch 3/50
# 308/308 [==============================] - 25s 80ms/step - loss: 2.3701 - val_loss: 2.3148
# Epoch 4/50
# 308/308 [==============================] - 25s 80ms/step - loss: 2.2265 - val_loss: 2.2126
# Epoch 5/50
# 308/308 [==============================] - 25s 80ms/step - loss: 2.1219 - val_loss: 2.1315
# Epoch 6/50
# 308/308 [==============================] - 25s 81ms/step - loss: 2.0360 - val_loss: 2.0753
# Epoch 7/50
# 308/308 [==============================] - 25s 81ms/step - loss: 1.9637 - val_loss: 2.0229
# Epoch 8/50
# 308/308 [==============================] - 25s 80ms/step - loss: 1.9000 - val_loss: 1.9808
# Epoch 9/50
# 308/308 [==============================] - 25s 80ms/step - loss: 1.8458 - val_loss: 1.9443
# Epoch 10/50
# 308/308 [==============================] - 25s 80ms/step - loss: 1.7969 - val_loss: 1.9151
# Epoch 11/50
# 308/308 [==============================] - 25s 80ms/step - loss: 1.7545 - val_loss: 1.8947
# Epoch 12/50
# 308/308 [==============================] - 25s 80ms/step - loss: 1.7157 - val_loss: 1.8747
# Epoch 13/50
# 308/308 [==============================] - 25s 81ms/step - loss: 1.6808 - val_loss: 1.8588
# Epoch 14/50
# 308/308 [==============================] - 25s 81ms/step - loss: 1.6484 - val_loss: 1.8497
# Epoch 15/50
# 308/308 [==============================] - 25s 80ms/step - loss: 1.6188 - val_loss: 1.8415
# Epoch 16/50
# 308/308 [==============================] - 25s 80ms/step - loss: 1.5911 - val_loss: 1.8321
# Epoch 17/50
# 308/308 [==============================] - 25s 81ms/step - loss: 1.5661 - val_loss: 1.8264
# Epoch 18/50
# 308/308 [==============================] - 25s 81ms/step - loss: 1.5424 - val_loss: 1.8242
# Epoch 19/50
# 308/308 [==============================] - 25s 81ms/step - loss: 1.5200 - val_loss: 1.8133
# Epoch 20/50
# 308/308 [==============================] - 25s 81ms/step - loss: 1.4985 - val_loss: 1.8124
# Epoch 21/50
# 308/308 [==============================] - 25s 81ms/step - loss: 1.4782 - val_loss: 1.8094
# Epoch 22/50
# 308/308 [==============================] - 25s 81ms/step - loss: 1.4605 - val_loss: 1.8072
# Epoch 23/50
# 308/308 [==============================] - 25s 81ms/step - loss: 1.4423 - val_loss: 1.8070
# Epoch 24/50
# 308/308 [==============================] - 25s 81ms/step - loss: 1.4247 - val_loss: 1.8081
# Epoch 25/50
# 308/308 [==============================] - 25s 81ms/step - loss: 1.4087 - val_loss: 1.8090
# Epoch 25: early stopping

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
src_index_to_word = src_tokenizer.index_word # 원문 단어 집합에서 정수 -> 단어를 얻음
tar_word_to_index = tar_tokenizer.word_index # 요약 단어 집합에서 단어 -> 정수를 얻음
tar_index_to_word = tar_tokenizer.index_word # 요약 단어 집합에서 정수 -> 단어를 얻음

# %%
# 인코더 설계
encoder_model = Model(inputs=encoder_inputs, outputs=[encoder_outputs, state_h, state_c])

# 이전 시점의 상태들을 저장하는 텐서
decoder_state_input_h = Input(shape=(hidden_size,))
decoder_state_input_c = Input(shape=(hidden_size,))

dec_emb2 = dec_emb_layer(decoder_inputs)

# 문장의 다음 단어를 예측하기 위해서 초기 상태(initial_state)를 이전 시점의 상태로 사용. 이는 뒤의 함수 decode_sequence()에 구현
# 훈련 과정에서와 달리 LSTM의 리턴하는 은닉 상태와 셀 상태인 state_h와 state_c를 버리지 않음.
decoder_outputs2, state_h2, state_c2 = decoder_lstm(dec_emb2, initial_state=[decoder_state_input_h, decoder_state_input_c])

# %%
# 어텐션 함수
decoder_hidden_state_input = Input(shape=(text_max_len, hidden_size))
attn_out_inf = attn_layer([decoder_outputs2, decoder_hidden_state_input])
decoder_inf_concat = Concatenate(axis=-1, name='concat')([decoder_outputs2, attn_out_inf])

# 디코더의 출력층
decoder_outputs2 = decoder_softmax_layer(decoder_inf_concat) 

# 최종 디코더 모델
decoder_model = Model(
    [decoder_inputs] + [decoder_hidden_state_input,decoder_state_input_h, decoder_state_input_c],
    [decoder_outputs2] + [state_h2, state_c2])

# %%
def decode_sequence(input_seq):
    # 입력으로부터 인코더의 상태를 얻음
    e_out, e_h, e_c = encoder_model.predict(input_seq)

     # <SOS>에 해당하는 토큰 생성
    target_seq = np.zeros((1,1))
    target_seq[0, 0] = tar_word_to_index['sostoken']

    stop_condition = False
    decoded_sentence = ''
    while not stop_condition: # stop_condition이 True가 될 때까지 루프 반복

        output_tokens, h, c = decoder_model.predict([target_seq] + [e_out, e_h, e_c])
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_token = tar_index_to_word[sampled_token_index]

        if (sampled_token!='eostoken'):
            decoded_sentence += ' '+sampled_token

        #  <eos>에 도달하거나 최대 길이를 넘으면 중단.
        if (sampled_token == 'eostoken'  or len(decoded_sentence.split()) >= (summary_max_len-1)):
            stop_condition = True

        # 길이가 1인 타겟 시퀀스를 업데이트
        target_seq = np.zeros((1,1))
        target_seq[0, 0] = sampled_token_index

        # 상태를 업데이트 합니다.
        e_h, e_c = h, c

    return decoded_sentence

# %% [markdown]
# ## Step 4. 실제 결과와 요약문 비교하기 (추상적 요약)
#
# 원래의 요약문(headlines 열)과 학습을 통해 얻은 추상적 요약의 결과를 비교해 보세요.

# %%
# 원문의 정수 시퀀스를 텍스트 시퀀스로 변환
def seq2text(input_seq):
    temp=''
    for i in input_seq:
        if (i!=0):
            temp = temp + src_index_to_word[i]+' '
    return temp

# 요약문의 정수 시퀀스를 텍스트 시퀀스로 변환
def seq2summary(input_seq):
    temp=''
    for i in input_seq:
        if ((i!=0 and i!=tar_word_to_index['sostoken']) and i!=tar_word_to_index['eostoken']):
            temp = temp + tar_index_to_word[i] + ' '
    return temp

# %%
for i in range(50, 100):
    print("원문 :", seq2text(encoder_input_test[i]))
    print("실제 요약 :", seq2summary(decoder_input_test[i]))
    print("예측 요약 :", decode_sequence(encoder_input_test[i].reshape(1, text_max_len)))
    print("\n")
# Out:
# 원문 : days rajasthan cm vasundhara raje said fight like protect state rajasthan congress chief sachin pilot claimed although raje biggest hunt farmers pilot said would defeat upcoming assembly elections manner able forget long time
# 실제 요약 : raj cm but her biggest is farmers congress
# 예측 요약 :  raj cm calls for priyanka
#
#
# 원문 : hundreds cars tuesday caught fire italian port city due floods north western area reason behind fire claimed salt water caused car batteries fire exact cost damage yet
# 실제 요약 : cars catch fire after by italy flood
# 예측 요약 :  fire breaks out in truck in delhi
#
#
# 원문 : ajay narayan secretary department expenditure appointed new finance secretary succeed retired november government order said monday fifty nine year old batch ias officer manipur tripura alumnus st college passed first class post history
# 실제 요약 : an to take over as new finance secretary from
# 예측 요약 :  appointed as new chief secretary
#
#
# 원문 : asked songs hi ho singer singh revealed feels listening singer also asked able bring much love romantic songs even question said response
# 실제 요약 : feel when to my own
# 예측 요약 :  was asked to show on
#
#
# 원문 : google acquired bengaluru based labs runs offline train tracking app train undisclosed amount google reportedly talks acquire startup august million train offers offline indian railways irctc using cell tower information locate trains lets users seat
# 실제 요약 : google acquires bengaluru based train app
# 예측 요약 :  google parent startup launches mumbai based train startup
#
#
# 원문 : delhi high court friday issued notice delhi government plea seeking lower legal drinking age years capital pointing minimum age voting obtaining driver license years petition drinking age required government youngsters delhi
# 실제 요약 : hc notice to delhi govt on plea to reduce legal age
# 예측 요약 :  delhi hc notice to centre for not having
#
#
# 원문 : icc anti corruption unit general manager alex revealed corrupt international cricket belong india added showed list sri lanka england players involved series better informed recently ex pakistan spinner danish revealed took money indian fix matches
# 실제 요약 : most in international cricket are indians icc
# 예측 요약 :  icc odi corruption charges
#
#
# 원문 : supreme court told centre action taken whose names national register citizens draft released assam government draft names lakh people nrc told centre frame standard operating procedures deal objections regarding nrc
# 실제 요약 : no action against those names not in sc
# 예측 요약 :  sc slams govt for in
#
#
# 원문 : pakistan army wednesday firing two places along line control jammu kashmir accounting second ceasefire violation day firing district sector district prompted indian army officials said per reports firing still
# 실제 요약 : pak opens fire along nd in day
# 예측 요약 :  pakistani soldiers killed in firing along
#
#
# 원문 : congress mla wednesday carried shell kerala assembly showing shell speaker mla claimed used youth congress protestors last week beyond date police still using later submitted shell speaker
# 실제 요약 : congress mla to kerala assembly
# 예측 요약 :  kerala mla to mla
#
#
# 원문 : swedish forward zlatan personally called la galaxy fan season ticket current season give lot joy happiness goals something else want cup bring also worry zlatan heard saying video call
# 실제 요약 : calls season ticket to him
# 예측 요약 :  to star in ipl
#
#
# 원문 : former ranji cricketer rajesh represented goa two first class matches eight list matches collapsed died aged batting local match non striker end collapsed dead hospital later sunday secretary cricket club said
# 실제 요약 : ex goa cricketer dies at after on field
# 예측 요약 :  former rajasthan cm dies in
#
#
# 원문 : tencent building research team auto drive team based california chinese gaming social media giant said job advertisements linkedin self driving car engineers california earlier year tencent received first licence conduct tests autonomous cars public roads china
# 실제 요약 : self driving car team in
# 예측 요약 :  startup to build self driving cars in us
#
#
# 원문 : year old canadian national named glad stone arrested allegedly using forged documents live years police said wednesday stone presented forged document police prepared advocate showed haryana address intelligence bureau local intelligence unit
# 실제 요약 : canadian held for living in for years
# 예측 요약 :  year old canadian police arrested for
#
#
# 원문 : charity group revealed women perform unpaid work worth trillion annually globally times annual turnover apple adding female face india observed unpaid work women country worth gdp report said country gender pay gap stands
# 실제 요약 : women work worth times apple
# 예측 요약 :  women tech startup in survey
#
#
# 원문 : addressing rally prime minister narendra modi tuesday accused telangana rashtra samithi government telangana state reason simple chandrababu naidu government state part andhra pradesh upa government added pm also called trs copy congress party
# 실제 요약 : government telangana pm narendra modi
# 예측 요약 :  pm modi has to andhra cm
#
#
# 원문 : year old pregnant woman allegedly gangraped uttar pradesh early hours friday police officials said incident came light woman gone field found unconscious state family members police launched search operation nab accused
# 실제 요약 : year old pregnant woman gangraped in uttar pradesh
# 예측 요약 :  woman gangraped by men in up
#
#
# 원문 : swedish id service acquired kerala based payments startup marking first acquisition india part deal co founder sony joy join vice president pay entire team retained company founded lets users send money directly bank accounts using mobile numbers
# 실제 요약 : makes st indian buys payments firm
# 예측 요약 :  acquires india first startup
#
#
# 원문 : electric company tesla ceo elon musk tuesday tweeted considering taking tesla private funding secured share price suggested musk buying outstanding shares company around higher share current price tweet pushed tesla shares higher
# 실제 요약 : tesla ceo elon musk says he is taking tesla private
# 예측 요약 :  elon musk tesla to sell in tesla stock
#
#
# 원문 : parineeti chopra said person believe dating one night stand relationships person believes serious committed relationships towards matters added think lived full life given heart said
# 실제 요약 : do not in dating or one night stand parineeti
# 예측 요약 :  parineeti is parineeti
#
#
# 원문 : indian railways decided give discount passengers food booked journey served time train discount next order food rail official said facility valid online offline purchase well cash refund
# 실제 요약 : railways to give for late food delivery in trains
# 예측 요약 :  railways to get trains to
#
#
# 원문 : ultra shorts web series status tells stories different people different relationships college student experience first love guy suddenly finds love life married couple happy sometimes relation beautiful head
# 실제 요약 : new web series of
# 예측 요약 :  web series is young
#
#
# 원문 : rbi deputy governor viral acharya said thursday rbi considering setting public credit database bank loans acharya suggested would managed public authority like central bank reporting loan details mandatory notably current database hosts credit information loans crore
# 실제 요약 : rbi may set up of bank loans deputy governor
# 예측 요약 :  rbi to open to loans
#
#
# 원문 : uber us canada regional manager meghan email sent employees drivers week said uber ban passengers spread hate practice discrimination neo nazi demonstration said uber recent virginia violence drivers right end trip feel uber added
# 실제 요약 : we will ban passengers over hate uber after attack
# 예측 요약 :  uber to stop drivers with drivers in uk
#
#
# 원문 : family late fashion designer kate confirmed father jr passed away wednesday one night funeral thursday failing health also recent death daughter kate committed suicide new york apartment two weeks ago
# 실제 요약 : father passes away one night before her
# 예측 요약 :  family of family found in
#
#
# 원문 : routine meeting supreme court judges chief justice india dipak misra monday said best comes vice president venkaiah naidu rejected opposition led impeachment motion misra meanwhile judges resolved form four judge team hold informal meetings discussing suggestions
# 실제 요약 : am doing my best cji during meeting
# 예측 요약 :  sc naidu to probe into prez
#
#
# 원문 : chinese smartphone maker oneplus first time entered top five premium android original equipment manufacturers globally years since company according research market monitor oneplus one fastest growing brands price segment driven strong sales india china uk
# 실제 요약 : oneplus enters top android in report
# 예측 요약 :  oneplus records first ever smartphone in years
#
#
# 원문 : prime minister narendra modi saturday announced crore improving roads national highways northeast next two three years facilitate better connectivity also dedicated nation km two lane national highway connecting western meghalaya inaugurated project
# 실제 요약 : pm modi announces cr for roads in
# 예측 요약 :  pm modi announces crore for
#
#
# 원문 : end year post facebook ceo mark zuckerberg said election interference harmful speech issues never fully solved facebook dna focus preventing harm services year old billionaire added however zuckerberg also said proud progress facebook made
# 실제 요약 : some of facebook issues can never be zuckerberg
# 예측 요약 :  zuckerberg is the right to be facebook
#
#
# 원문 : maharashtra government install plastic bottle machines across state ensure proper disposal plastic bottles machines purchased corporate social responsibility funds installed public places including tourist spots markets gardens high comes state lifted ban small plastic bottles
# 실제 요약 : maharashtra to plastic
# 예측 요약 :  maha govt to use plastic to plastic
#
#
# 원문 : two faces less month born south africa born rare condition called two two three eyes gone viral online followers facebook taken got
# 실제 요약 : with faces less than month after birth
# 예측 요약 :  two years ago
#
#
# 원문 : pm narendra modi official channel video sharing platform youtube million subscribers channel regularly videos speeches radio programme mann ki baat several public health family welfare minister jp congratulated said testimony common people love pm modi
# 실제 요약 : pm modi youtube hits million
# 예측 요약 :  pm modi shares video of youtube videos
#
#
# 원문 : russian intelligence agencies spying emails former spy sergei daughter least five years duo last month uk national security adviser mark said added russia trained special units use nerve agents technical means operational experience motive attack
# 실제 요약 : russia on of ex spy daughter uk
# 예측 요약 :  russia had to be used to spy in russia
#
#
# 원문 : turkish airlines saturday announced offer laptops business class passengers us uk bound flights laptops secure protect users privacy automatically personal data turkish airlines added move comes uk us banned travellers several muslim majority countries carrying large electronic devices
# 실제 요약 : airlines offers to business class
# 예측 요약 :  germany to allow flyers to remove from
#
#
# 원문 : hollywood actress rose starred deepika padukone return cage supported deepika ongoing row padmavati shock reading dear friend going absolute strength courage deepika one strongest women know tweeted
# 실제 요약 : co star deepika in padmavati row
# 예측 요약 :  deepika to deepika in deepika
#
#
# 원문 : fifa world cup first time iceland football team performed traditional celebration fans iceland population registered football players smallest nation play world cup celebration made popular iceland campaign
# 실제 요약 : watch celebrate wc with
# 예측 요약 :  fifa world cup trophy
#
#
# 원문 : actress aditi rao turned designer gaurav gupta india week walked runway gown collection paired makeup accessories collection inspired nature forest fantasy space almost like world happening moon way said gaurav
# 실제 요약 : rao for at week
# 예측 요약 :  rao to host at fashion week
#
#
# 원문 : nobel peace prize winner watching shah rukh khan zero family said video message hello shah rukh khan hope one day meet person would big day see nice watch movie big fan best amazing said
# 실제 요약 : hope one day we can meet it would be my big day to srk
# 예측 요약 :  srk is like someone to him on meeting srk
#
#
# 원문 : sharma year old indian found dead apartment dubai wednesday sharma popularly known fifth year student academy higher education body referred forensic medicine department report showed death local media reported
# 실제 요약 : year old indian found dead in dubai
# 예측 요약 :  year old found dead in australia
#
#
# 원문 : world largest designed built work like human brain switched first time made one million complete million million actions per second machine model biological real time machine planet researchers claim
# 실제 요약 : human brain like on for st time
# 예측 요약 :  world largest robot to be made
#
#
# 원문 : per bcci new contract structure indian women cricketers top earn lakh annually half amount lowest paid male cricketers get women players grade get lakh newly introduced grade get lakh
# 실제 요약 : top women cricketers to earn half of paid men players
# 예측 요약 :  bcci to earn lakh lakh women players earn
#
#
# 원문 : kartik bhumi pednekar star upcoming remake film aur confirming news shared picture co stars film makers wrote super start ride shooting film begin february per reports
# 실제 요약 : to star in remake
# 예측 요약 :  to star in upcoming film
#
#
# 원문 : shooter shared picture india first ever individual olympic gold medal august beijing ninth anniversary win remember journey process gold medal outcome wrote gold men metre air rifle
# 실제 요약 : shares pic of india st olympic gold on
# 예측 요약 :  year old st indian to win gold at cwg
#
#
# 원문 : spain based researchers confined light less space one thick smallest possible team interacting strongly light gap metal form carbon could switched applying electrical
# 실제 요약 : scientists light to space of make new record
# 예측 요약 :  scientists create of light
#
#
# 원문 : paytm payments bank ceo recent interview talking paytm operating cost said investing million operations also said aggressive expansion india last week rbi released directions operations digital payment
# 실제 요약 : will put mn in paytm payments bank ceo
# 예측 요약 :  paytm ceo calls paytm payments bank of million
#
#
# 원문 : substance discovered germany location secret nazi nuclear test facility world war ii according reports authorities evacuated surrounding area man investigated unauthorised possession substance reports added
# 실제 요약 : at secret nuclear
# 예측 요약 :  german bomb bomb
#
#
# 원문 : bjp president amit shah wednesday met actress madhuri dixit mumbai part party programme maharashtra chief minister devendra fadnavis also present meeting shah also scheduled meet shiv sena chief uddhav thackeray whose party said ally bjp polls
# 실제 요약 : bjp president amit shah meets in mumbai
# 예측 요약 :  amit shah to visit mumbai mumbai
#
#
# 원문 : national green tribunal wednesday ordered punjab government submit fine crore environmental compensation rivers ngt given two weeks time deposit fine ngt taken view pollution levels two rivers dead found floating river
# 실제 요약 : punjab govt fined crore by ngt over river pollution
# 예측 요약 :  ngt ngt to fine on cr fine
#
#
# 원문 : actor andrew said comment gay man without physical act taken context made remark talking gay role play america andrew explained statement meant fully prepared committed role modern culture
# 실제 요약 : my gay without act remark
# 예측 요약 :  gay man once got gay
#
#
# 원문 : weeks festival organisers borrowed million last minute bid fund music documents show nearly million remains rest spent one investors funding member festival million sued organisers
# 실제 요약 : festival was in of debt before it
# 예측 요약 :  to crore in

# %% [markdown]
# ## Step 5. Summa 을 이용해서 추출적 요약해보기
#
# 추상적 요약은 추출적 요약과는 달리 문장의 표현력을 다양하게 가져갈 수 있지만, 추출적 요약에 비해서 난이도가 높아요. 반대로 말하면 추출적 요약은 추상적 요약에 비해 난이도가 낮고 기존 문장에서 문장을 꺼내오는 것이므로 잘못된 요약이 나올 가능성이 낮아요.

# %%
import urllib.request
urllib.request.urlretrieve("https://raw.githubusercontent.com/sunnysai12345/News_Summary/master/news_summary_more.csv", filename="news_summary_more.csv")
data1 = pd.read_csv('news_summary_more.csv', encoding='iso-8859-1')

# %%
import requests
from summa.summarizer import summarize

# %%
print('Summary:')
print('다시 한 번 돌려보아요')
print(summarize(data1['text'][1], ratio=0.4, split=True))
print('쨘!!')
# Out:
# Summary:
# 다시 한 번 돌려보아요
# ['Users get one CRED coin per rupee of bill paid, which can be used to avail rewards from brands like Ixigo, BookMyShow, UberEats, Cult.Fit and more.']
# 쨘!!

# %%
for idx, (head, text) in enumerate(zip(data1['headlines'], data1['text'])):
    if idx == 10:
        break
    print("원문 :", text)
    print("실제 요약 :", head)
    print("예측 요약 :", summarize(text, ratio=0.35))
    print("\n")
# Out:
# 원문 : Saurav Kant, an alumnus of upGrad and IIIT-B's PG Program in Machine learning and Artificial Intelligence, was a Sr Systems Engineer at Infosys with almost 5 years of work experience. The program and upGrad's 360-degree career support helped him transition to a Data Scientist at Tech Mahindra with 90% salary hike. upGrad's Online Power Learning has powered 3 lakh+ careers.
# 실제 요약 : upGrad learner switches to career in ML & Al with 90% salary hike
# 예측 요약 : upGrad's Online Power Learning has powered 3 lakh+ careers.
#
#
# 원문 : Kunal Shah's credit card bill payment platform, CRED, gave users a chance to win free food from Swiggy for one year. Pranav Kaushik, a Delhi techie, bagged this reward after spending 2000 CRED coins. Users get one CRED coin per rupee of bill paid, which can be used to avail rewards from brands like Ixigo, BookMyShow, UberEats, Cult.Fit and more.
# 실제 요약 : Delhi techie wins free food from Swiggy for one year on CRED
# 예측 요약 : Users get one CRED coin per rupee of bill paid, which can be used to avail rewards from brands like Ixigo, BookMyShow, UberEats, Cult.Fit and more.
#
#
# 원문 : New Zealand defeated India by 8 wickets in the fourth ODI at Hamilton on Thursday to win their first match of the five-match ODI series. India lost an international match under Rohit Sharma's captaincy after 12 consecutive victories dating back to March 2018. The match witnessed India getting all out for 92, their seventh lowest total in ODI cricket history.
# 실제 요약 : New Zealand end Rohit Sharma-led India's 12-match winning streak
# 예측 요약 : The match witnessed India getting all out for 92, their seventh lowest total in ODI cricket history.
#
#
# 원문 : With Aegon Life iTerm Insurance plan, customers can enjoy tax benefits on your premiums paid and save up to Ã¢ÂÂ¹46,800^ on taxes. The plan provides life cover up to the age of 100 years. Also, customers have options to insure against Critical Illnesses, Disability and Accidental Death Benefit Rider with a life cover up to the age of 80 years.
# 실제 요약 : Aegon life iTerm insurance plan helps customers save tax
# 예측 요약 : Also, customers have options to insure against Critical Illnesses, Disability and Accidental Death Benefit Rider with a life cover up to the age of 80 years.
#
#
# 원문 : Speaking about the sexual harassment allegations against Rajkumar Hirani, Sonam Kapoor said, "I've known Hirani for many years...What if it's not true, the [#MeToo] movement will get derailed." "In the #MeToo movement, I always believe a woman. But in this case, we need to reserve our judgment," she added. Hirani has been accused by an assistant who worked in 'Sanju'.
# 실제 요약 : Have known Hirani for yrs, what if MeToo claims are not true: Sonam
# 예측 요약 : Speaking about the sexual harassment allegations against Rajkumar Hirani, Sonam Kapoor said, "I've known Hirani for many years...What if it's not true, the [#MeToo] movement will get derailed." "In the #MeToo movement, I always believe a woman.
#
#
# 원문 : Pakistani singer Rahat Fateh Ali Khan has denied receiving any notice from the Enforcement Directorate over allegedly smuggling foreign currency out of India. "It would have been better if the authorities would have served the notice first if any and then publicised this," reads a press release issued on behalf of Rahat. The statement further called the allegation "bizarre".
# 실제 요약 : Rahat Fateh Ali Khan denies getting notice for smuggling currency
# 예측 요약 : Pakistani singer Rahat Fateh Ali Khan has denied receiving any notice from the Enforcement Directorate over allegedly smuggling foreign currency out of India.
#
#
# 원문 : India recorded their lowest ODI total in New Zealand after getting all out for 92 runs in 30.5 overs in the fourth ODI at Hamilton on Thursday. Seven of India's batsmen were dismissed for single-digit scores, while their number ten batsman Yuzvendra Chahal top-scored with 18*(37). India's previous lowest ODI total in New Zealand was 108.
# 실제 요약 : India get all out for 92, their lowest ODI total in New Zealand
# 예측 요약 : India's previous lowest ODI total in New Zealand was 108.
#
#
# 원문 : Weeks after ex-CBI Director Alok Verma told the Department of Personnel and Training to consider him retired, the Home Ministry asked him to join work on the last day of his fixed tenure as Director on Thursday. The ministry directed him to immediately join as DG, Fire Services, the post he was transferred to after his removal as CBI chief.
# 실제 요약 : Govt directs Alok Verma to join work 1 day before his retirement
# 예측 요약 :
#
#
# 원문 : Andhra Pradesh CM N Chandrababu Naidu has said, "When I met then US President Bill Clinton, I addressed him as Mr Clinton, not as 'sir'. (PM Narendra) Modi is my junior in politics...I addressed him as sir 10 times." "I did this...to satisfy his ego in the hope that he will do justice to the state," he added.
# 실제 요약 : Called PM Modi 'sir' 10 times to satisfy his ego: Andhra CM
# 예측 요약 :
#
#
# 원문 : Congress candidate Shafia Zubair won the Ramgarh Assembly seat in Rajasthan, by defeating BJP's Sukhwant Singh with a margin of 12,228 votes in the bypoll. With this victory, Congress has taken its total to 100 seats in the 200-member assembly. The election to the Ramgarh seat was delayed due to the death of sitting MLA and BSP candidate Laxman Singh.
# 실제 요약 : Cong wins Ramgarh bypoll in Rajasthan, takes total to 100 seats
# 예측 요약 : Congress candidate Shafia Zubair won the Ramgarh Assembly seat in Rajasthan, by defeating BJP's Sukhwant Singh with a margin of 12,228 votes in the bypoll.

# %%
######### 실패ㅐㅐㅐㅐㅐㅐㅐㅐㅐㅐㅐㅐㅐㅐㅐㅐㅐㅐㅐㅐㅐㅐ
test = seq2summary(decoder_input_test[777])

for idx, (head, text) in enumerate(zip(data['headlines'], data['text'])):
    if test in head:
      print(head)

# %% [markdown]
# ## 결과
#
# - 노드에 나온 코드를 따라서 실행해본 결과 추상적 요약이 실제 요약과는 차이가 났다.
#
# - 최대 문장으로 자르지 않고 했는데, 문장길이에 따른 학습이 궁금해서 진행해보았다.

# %%
text_max_len = 45
summary_max_len = 13

# %%
encoder_input_train = pad_sequences(encoder_input_train, maxlen=text_max_len, padding='post')
encoder_input_test = pad_sequences(encoder_input_test, maxlen=text_max_len, padding='post')

decoder_input_train = pad_sequences(decoder_input_train, maxlen=summary_max_len, padding='post')
decoder_target_train = pad_sequences(decoder_target_train, maxlen=summary_max_len, padding='post')

decoder_input_test = pad_sequences(decoder_input_test, maxlen=summary_max_len, padding='post')
decoder_target_test = pad_sequences(decoder_target_test, maxlen=summary_max_len, padding='post')

# %%
from tensorflow.keras.layers import Input, LSTM, Embedding, Dense, Concatenate, TimeDistributed
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint


# 인코더 설계 시작
embedding_dim = 128
hidden_size = 256

# 인코더
encoder_inputs = Input(shape=(text_max_len,))

# 인코더의 임베딩 층
enc_emb = Embedding(src_vocab, embedding_dim)(encoder_inputs)

# 인코더의 LSTM 1
# encoder_lstm1 = LSTM(hidden_size, return_sequences=True, return_state=True ,dropout = 0.4, recurrent_dropout = 0.4)
encoder_lstm1 = LSTM(hidden_size, return_sequences=True, return_state=True ,dropout = 0.4)
encoder_output1, state_h1, state_c1 = encoder_lstm1(enc_emb)

# 인코더의 LSTM 2
# encoder_lstm2 = LSTM(hidden_size, return_sequences=True, return_state=True, dropout=0.4, recurrent_dropout=0.4)
encoder_lstm2 = LSTM(hidden_size, return_sequences=True, return_state=True, dropout=0.4)
encoder_output2, state_h2, state_c2 = encoder_lstm2(encoder_output1)

# 인코더의 LSTM 3
# encoder_lstm3 = LSTM(hidden_size, return_state=True, return_sequences=True, dropout=0.4, recurrent_dropout=0.4)
encoder_lstm3 = LSTM(hidden_size, return_state=True, return_sequences=True, dropout=0.4)
encoder_outputs, state_h, state_c= encoder_lstm3(encoder_output2)

# 디코더 설계
decoder_inputs = Input(shape=(None,))

# 디코더의 임베딩 층
dec_emb_layer = Embedding(tar_vocab, embedding_dim)
dec_emb = dec_emb_layer(decoder_inputs)

# 디코더의 LSTM
# decoder_lstm = LSTM(hidden_size, return_sequences=True, return_state=True, dropout=0.4, recurrent_dropout=0.2)
decoder_lstm = LSTM(hidden_size, return_sequences=True, return_state=True, dropout=0.4)
decoder_outputs, _, _ = decoder_lstm(dec_emb, initial_state=[state_h, state_c])

from tensorflow.keras.layers import AdditiveAttention

# 어텐션 층(어텐션 함수)
attn_layer = AdditiveAttention(name='attention_layer')

# 인코더와 디코더의 모든 time step의 hidden state를 어텐션 층에 전달하고 결과를 리턴
attn_out = attn_layer([decoder_outputs, encoder_outputs])


# 어텐션의 결과와 디코더의 hidden state들을 연결
decoder_concat_input = Concatenate(axis=-1, name='concat_layer')([decoder_outputs, attn_out])

# 디코더의 출력층
decoder_softmax_layer = Dense(tar_vocab, activation='softmax')
decoder_softmax_outputs = decoder_softmax_layer(decoder_concat_input)

# 모델 정의
model = Model([encoder_inputs, decoder_inputs], decoder_softmax_outputs)
model.summary()

model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy')
es = EarlyStopping(monitor='val_loss', patience=2, verbose=1)
history = model.fit(x=[encoder_input_train, decoder_input_train], y=decoder_target_train, \
          validation_data=([encoder_input_test, decoder_input_test], decoder_target_test), \
          batch_size=256, callbacks=[es], epochs=50)

plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()
# Out:
# Model: "model_10"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_18 (InputLayer)          [(None, 45)]         0           []
#
#  embedding_8 (Embedding)        (None, 45, 128)      1024000     ['input_18[0][0]']
#
#  lstm_16 (LSTM)                 [(None, 45, 256),    394240      ['embedding_8[0][0]']
#                                  (None, 256),
#                                  (None, 256)]
#
#  input_19 (InputLayer)          [(None, None)]       0           []
#
#  lstm_17 (LSTM)                 [(None, 45, 256),    525312      ['lstm_16[0][0]']
#                                  (None, 256),
#                                  (None, 256)]
#
#  embedding_9 (Embedding)        (None, None, 128)    256000      ['input_19[0][0]']
#
#  lstm_18 (LSTM)                 [(None, 45, 256),    525312      ['lstm_17[0][0]']
#                                  (None, 256),
#                                  (None, 256)]
#
#  lstm_19 (LSTM)                 [(None, None, 256),  394240      ['embedding_9[0][0]',
#                                  (None, 256),                     'lstm_18[0][1]',
#                                  (None, 256)]                     'lstm_18[0][2]']
#
#  attention_layer (AdditiveAtten  (None, None, 256)   256         ['lstm_19[0][0]',
#  tion)                                                            'lstm_18[0][0]']
#
#  concat_layer (Concatenate)     (None, None, 512)    0           ['lstm_19[0][0]',
#                                                                   'attention_layer[0][0]']
#
#  dense_4 (Dense)                (None, None, 2000)   1026000     ['concat_layer[0][0]']
#
# ==================================================================================================
# Total params: 4,145,360
# Trainable params: 4,145,360
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/50
# 308/308 [==============================] - 28s 68ms/step - loss: 2.1368 - val_loss: 1.9741
# Epoch 2/50
# 308/308 [==============================] - 19s 63ms/step - loss: 1.8998 - val_loss: 1.8553
# Epoch 3/50
# 308/308 [==============================] - 19s 63ms/step - loss: 1.7938 - val_loss: 1.7823
# Epoch 4/50
# 308/308 [==============================] - 19s 62ms/step - loss: 1.7213 - val_loss: 1.7262
# Epoch 5/50
# 308/308 [==============================] - 19s 62ms/step - loss: 1.6622 - val_loss: 1.6867
# Epoch 6/50
# 308/308 [==============================] - 19s 62ms/step - loss: 1.6145 - val_loss: 1.6590
# Epoch 7/50
# 308/308 [==============================] - 19s 63ms/step - loss: 1.5744 - val_loss: 1.6352
# Epoch 8/50
# 308/308 [==============================] - 19s 62ms/step - loss: 1.5404 - val_loss: 1.6209
# Epoch 9/50
# 308/308 [==============================] - 19s 63ms/step - loss: 1.5105 - val_loss: 1.6068
# Epoch 10/50
# 308/308 [==============================] - 19s 62ms/step - loss: 1.4828 - val_loss: 1.6030
# Epoch 11/50
# 308/308 [==============================] - 19s 62ms/step - loss: 1.4568 - val_loss: 1.5948
# Epoch 12/50
# 308/308 [==============================] - 19s 62ms/step - loss: 1.4334 - val_loss: 1.5873
# Epoch 13/50
# 308/308 [==============================] - 19s 62ms/step - loss: 1.4111 - val_loss: 1.5877
# Epoch 14/50
# 308/308 [==============================] - 19s 63ms/step - loss: 1.3892 - val_loss: 1.5833
# Epoch 15/50
# 308/308 [==============================] - 19s 62ms/step - loss: 1.3697 - val_loss: 1.5860
# Epoch 16/50
# 308/308 [==============================] - 19s 62ms/step - loss: 1.3496 - val_loss: 1.5872
# Epoch 16: early stopping

# %%
src_index_to_word = src_tokenizer.index_word # 원문 단어 집합에서 정수 -> 단어를 얻음
tar_word_to_index = tar_tokenizer.word_index # 요약 단어 집합에서 단어 -> 정수를 얻음
tar_index_to_word = tar_tokenizer.index_word # 요약 단어 집합에서 정수 -> 단어를 얻음

# 인코더 설계
encoder_model = Model(inputs=encoder_inputs, outputs=[encoder_outputs, state_h, state_c])

# 이전 시점의 상태들을 저장하는 텐서
decoder_state_input_h = Input(shape=(hidden_size,))
decoder_state_input_c = Input(shape=(hidden_size,))

dec_emb2 = dec_emb_layer(decoder_inputs)

# 문장의 다음 단어를 예측하기 위해서 초기 상태(initial_state)를 이전 시점의 상태로 사용. 이는 뒤의 함수 decode_sequence()에 구현
# 훈련 과정에서와 달리 LSTM의 리턴하는 은닉 상태와 셀 상태인 state_h와 state_c를 버리지 않음.
decoder_outputs2, state_h2, state_c2 = decoder_lstm(dec_emb2, initial_state=[decoder_state_input_h, decoder_state_input_c])

# 어텐션 함수
decoder_hidden_state_input = Input(shape=(text_max_len, hidden_size))
attn_out_inf = attn_layer([decoder_outputs2, decoder_hidden_state_input])
decoder_inf_concat = Concatenate(axis=-1, name='concat')([decoder_outputs2, attn_out_inf])

# 디코더의 출력층
decoder_outputs2 = decoder_softmax_layer(decoder_inf_concat) 

# 최종 디코더 모델
decoder_model = Model(
    [decoder_inputs] + [decoder_hidden_state_input,decoder_state_input_h, decoder_state_input_c],
    [decoder_outputs2] + [state_h2, state_c2])

# %%
for i in range(50, 100):
    print("원문 :", seq2text(encoder_input_test[i]))
    print("실제 요약 :", seq2summary(decoder_input_test[i]))
    print("예측 요약 :", decode_sequence(encoder_input_test[i].reshape(1, text_max_len)))
    print("\n")
# Out:
# 원문 : via suspension cable delivering water aerial water filled yamuna dropped site
# 실제 요약 : air force help fight the over hour delhi fire
# 예측 요약 :  in
#
#
# 원문 : slammed congress banning cow slaughter tenure kerala remarks come amid crackdown illegal slaughterhouses several bjp ruled states
# 실제 요약 : candidate good if elected
# 예측 요약 :  in
#
#
# 원문 : defeating bjp candidate singh margin votes meanwhile state congress president sachin pilot took oath deputy chief minister
# 실제 요약 : rajasthan cm sachin pilot as deputy cm
# 예측 요약 :  in himachal pradesh
#
#
# 원문 : world counsel said dera sacha sauda properties attached leaving client position pay court however dismissed plea directed pay within days
# 실제 요약 : fine have world ram rahim to hc
# 예측 요약 :  of
#
#
# 원문 : actress said girls body experienced life nnnn
# 실제 요약 : actress on body
# 예측 요약 :  to be on
#
#
# 원문 : several tata group firms denying allegations tata sons said due processes followed relation removal court noted statements made extraordinary general meeting notices nature
# 실제 요약 : in defamation case
# 예측 요약 :  to leave
#
#
# 원문 : sushant talked instead heading stanford university received offer dropped college went mumbai started working background dancer
# 실제 요약 : my dad tells me sushant
# 예측 요약 :  for
#
#
# 원문 : home minister likely bilateral meetings ministers member states official statement stated notably member countries include china pakistan russia among others
# 실제 요약 : to attend meet in
# 예측 요약 :  to india
#
#
# 원문 : venture tata sons india obtained normal channels cbi alleged airasia government officials change rules get overseas flying rights
# 실제 요약 : done without payments
# 예측 요약 :  to india
#
#
# 원문 : machine police recovered fake currency nearly lakh house raid part anti money laundering drive
# 실제 요약 : leader arrested for fake currency
# 예측 요약 :  in delhi
#
#
# 원문 : aditya stopped airport since luggage cabin limit aditya seen threatening airline staff saying nahi naam aditya narayan
# 실제 요약 : airlines staff
# 예측 요약 :  woman to pay for
#
#
# 원문 : calling biggest haul year man flying singapore reportedly hidden bars worth crore kept legs
# 실제 요약 : with gold bars in desh
# 예측 요약 :  to get
#
#
# 원문 : england july kohli reportedly test afghanistan june third indian play county season cheteshwar pujara ishant sharma
# 실제 요약 : to make debut before england tour
# 예측 요약 :  to play in test cricket
#
#
# 원문 : privacy counsel peter said google invested human years thousands products added said take full week send notices updated privacy policy worldwide
# 실제 요약 : to with new eu rules
# 예측 요약 :  to us
#
#
# 원문 : generate power body movements like fingers throat team claims electricity generated six could charge laptop mobile phone
# 실제 요약 : from
# 예측 요약 :  to detect
#
#
# 원문 : tillerson unaware reason meanwhile trump admitted tillerson things praising state secretary mike pompeo tremendous energy trump said always pompeo
# 실제 요약 : state dept official
# 예측 요약 :  to us trump
#
#
# 원문 : mla pratap reportedly attacked bjp mla belt speaker suspended rest session congress mlas staged walk protest
# 실제 요약 : mlas each other inside gujarat assembly
# 예측 요약 :  in taka cm
#
#
# 원문 : animal rights talking film saif earlier said project till date fight two brothers
# 실제 요약 : khan pics from sets of online
# 예측 요약 :  in film
#
#
# 원문 : holy book khattar added books bought company price comes state government criticised move
# 실제 요약 : know its value on for
# 예측 요약 :  of
#
#
# 원문 : mechanism device take longer seconds identify currently printing based identification marks help challenged currency
# 실제 요약 : to help notes
# 예측 요약 :  to
#
#
# 원문 : second placed madrid sunday win barcelona points table eight point gap ahead second placed madrid messi third free kick week sixth overall season
# 실제 요약 : goal helps bar beat go clear
# 예측 요약 :  to win in
#
#
# 원문 : challenging love sanjay added period drama set mughal era story war love
# 실제 요약 : on being to films
# 예측 요약 :  to be in my film
#
#
# 원문 : indian captain wicket keeper ms dhoni got really good game sense well way sort another adam gilchrist ponting added year old indian wicket keeper
# 실제 요약 : make lot more test than ms dhoni
# 예측 요약 :  tweets user on dhoni
#
#
# 원문 : drug lord run five times added people killed philippines war drugs since duterte became president
# 실제 요약 : drugs war will not justice
# 예측 요약 :  to kill philippine prez
#
#
# 원문 : suicide attack claimed islamic state militant group security forces area investigations underway reports added
# 실제 요약 : in pak suicide attack by isis
# 예측 요약 :  attack on
#
#
# 원문 : icici bank axis bank range functions include bill collection letters credit opening accounts trade use blockchain technology expected reduce risk fraud loc transactions
# 실제 요약 : up based trade network with banks
# 예측 요약 :  to crore
#
#
# 원문 : body found dumped puducherry lake taken government hospital police complaint registered matter probe underway
# 실제 요약 : head into tn police
# 예측 요약 :  in bihar
#
#
# 원문 : win five consecutive losses tournament yuvraj singh scored ball hyderabad anderson ball towards end innings helped delhi win balls spare
# 실제 요약 : hyderabad to register first win after
# 예측 요약 :  to win in
#
#
# 원문 : state also announced lakh deceased injured modi assured possible help assistance centre situation
# 실제 요약 : announces crore for flood hit gujarat
# 예측 요약 :  in bihar
#
#
# 원문 : final kg category year old mother three currently tied taylor ireland five gold medals world championships
# 실제 요약 : medal after
# 예측 요약 :  gold at cwg
#
#
# 원문 : restoration company statue note dating back popular economic situation political religious matters famous people among
# 실제 요약 : note found inside statue in spain
# 예측 요약 :  in india
#
#
# 원문 : loans banks terming loan waiver misleading added political stunt congress solution farmers said
# 실제 요약 : not of farmers pm modi
# 예측 요약 :  loans to pnb
#
#
# 원문 : report confirmed suspected someone else made signature accused train late reached meerut examination officials said
# 실제 요약 : sign does not match
# 예측 요약 :  to escape
#
#
# 원문 : great support people iran appropriate time respect people iran try take back corrupt government trump tweeted earlier trump called iranian regime
# 실제 요약 : at time trump
# 예측 요약 :  iran to iran
#
#
# 원문 : residents health important profits court asked authorities look fire safety dealing unauthorised
# 실제 요약 : of illegal in delhi sc
# 예측 요약 :  in
#
#
# 원문 : girl holding featured raj kapoor film naam amul official twitter handle sharing poster wrote amul precious lost rk studios fire
# 실제 요약 : on fire at
# 예측 요약 :  for
#
#
# 원문 : pakistan said pakistan needed nine runs win six balls nehra ran towards ganguly said main aap main match win
# 실제 요약 : ganguly in odi against pak
# 예측 요약 :  to win vs pakistan
#
#
# 원문 : nasa satellite television experiment launched bringing cable television rural india padma awardee passed away december
# 실제 요약 : had tv to india
# 예측 요약 :  earth nasa
#
#
# 원문 : department led gujarat energy minister saurabh patel working creating policy provide required infrastructure mass run electric vehicles patel said stations charged batteries available manner similar existing petrol pumps
# 실제 요약 : asks ola uber to start electric taxi services
# 예측 요약 :  electric vehicles in
#
#
# 원문 : final sunday reacting spectators federer said guys make nervous guys make practice guys fill federer father also began crying standing crowd
# 실제 요약 : down after winning record th grand slam
# 예측 요약 :  to win tennis
#
#
# 원문 : banks collectively lost nearly crore cyber frauds less total money lost frauds cyber frauds constituted almost one third banking frauds
# 실제 요약 : in fy rbi
# 예측 요약 :  of bank
#
#
# 원문 : said added nda government need five years fulfil promises
# 실제 요약 : not in good state as am not fm bjp mp swamy
# 예측 요약 :  pm modi
#
#
# 원문 : cockpit two flights last year pilot bought full tickets also ordered pay wife journey
# 실제 요약 : suspended fined lakh for wife in
# 예측 요약 :  to be on
#
#
# 원문 : kashmir militant heard saying people considered families contest elections burden families life
# 실제 요약 : poll candidates in
# 예측 요약 :  in pakistan
#
#
# 원문 : put picture almost twin cousin arjun kapoor wrote alongside photo sonam father anil kapoor younger brother arjun father boney kapoor film producer
# 실제 요약 : shares pic with arjun kapoor
# 예측 요약 :  on sonam kapoor
#
#
# 원문 : comes cm vasundhara raje called late night meeting senior ministers bureaucrats per reports government might provisions bill prompted several protests
# 실제 요약 : to review bill public from probe
# 예측 요약 :  in
#
#
# 원문 : reports rebel pdp mlas touch bjp bjp june ended alliance pdp following mufti resigned cm governor rule imposed
# 실제 요약 : results if delhi tries to break
# 예측 요약 :  in taka
#
#
# 원문 : journalists broke official secrets act added said people read judgment
# 실제 요약 : do with press freedom
# 예측 요약 :  to women on metoo
#
#
# 원문 : basic services including pick delivery cash cheque books provided rbi said cases banks senior citizens differently abled persons banking facilities branches reported
# 실제 요약 : above by dec rbi
# 예측 요약 :  of
#
#
# 원문 : vehicle protesters around people killed others injured since began april
# 실제 요약 : vehicle into
# 예측 요약 :  attack on

# %% [markdown]
# ### 결과
#
# - 글자수를 잘라서 학습을 시키니 요약문의 글자수가 줄어버려서 제대로 요약하지 못하는 것을 확인할 수 있다.

# %%
text_max_len = 60
summary_max_len = 16

# %%
encoder_input_train = pad_sequences(encoder_input_train, maxlen=text_max_len, padding='post')
encoder_input_test = pad_sequences(encoder_input_test, maxlen=text_max_len, padding='post')

decoder_input_train = pad_sequences(decoder_input_train, maxlen=summary_max_len, padding='post')
decoder_target_train = pad_sequences(decoder_target_train, maxlen=summary_max_len, padding='post')

decoder_input_test = pad_sequences(decoder_input_test, maxlen=summary_max_len, padding='post')
decoder_target_test = pad_sequences(decoder_target_test, maxlen=summary_max_len, padding='post')

# %%
from tensorflow.keras.layers import Input, LSTM, Embedding, Dense, Concatenate, TimeDistributed
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint


# 인코더 설계 시작
embedding_dim = 256
hidden_size = 512

# 인코더
encoder_inputs = Input(shape=(text_max_len,))

# 인코더의 임베딩 층
enc_emb = Embedding(src_vocab, embedding_dim)(encoder_inputs)

# 인코더의 LSTM 1
# encoder_lstm1 = LSTM(hidden_size, return_sequences=True, return_state=True ,dropout = 0.4, recurrent_dropout = 0.4)
encoder_lstm1 = LSTM(hidden_size, return_sequences=True, return_state=True ,dropout = 0.4)
encoder_output1, state_h1, state_c1 = encoder_lstm1(enc_emb)

# 인코더의 LSTM 2
# encoder_lstm2 = LSTM(hidden_size, return_sequences=True, return_state=True, dropout=0.4, recurrent_dropout=0.4)
encoder_lstm2 = LSTM(hidden_size, return_sequences=True, return_state=True, dropout=0.4)
encoder_output2, state_h2, state_c2 = encoder_lstm2(encoder_output1)

# 인코더의 LSTM 3
# encoder_lstm3 = LSTM(hidden_size, return_state=True, return_sequences=True, dropout=0.4, recurrent_dropout=0.4)
encoder_lstm3 = LSTM(hidden_size, return_state=True, return_sequences=True, dropout=0.4)
encoder_outputs, state_h, state_c= encoder_lstm3(encoder_output2)

# 디코더 설계
decoder_inputs = Input(shape=(None,))

# 디코더의 임베딩 층
dec_emb_layer = Embedding(tar_vocab, embedding_dim)
dec_emb = dec_emb_layer(decoder_inputs)

# 디코더의 LSTM
# decoder_lstm = LSTM(hidden_size, return_sequences=True, return_state=True, dropout=0.4, recurrent_dropout=0.2)
decoder_lstm = LSTM(hidden_size, return_sequences=True, return_state=True, dropout=0.4)
decoder_outputs, _, _ = decoder_lstm(dec_emb, initial_state=[state_h, state_c])

from tensorflow.keras.layers import AdditiveAttention

# 어텐션 층(어텐션 함수)
attn_layer = AdditiveAttention(name='attention_layer')

# 인코더와 디코더의 모든 time step의 hidden state를 어텐션 층에 전달하고 결과를 리턴
attn_out = attn_layer([decoder_outputs, encoder_outputs])


# 어텐션의 결과와 디코더의 hidden state들을 연결
decoder_concat_input = Concatenate(axis=-1, name='concat_layer')([decoder_outputs, attn_out])

# 디코더의 출력층
decoder_softmax_layer = Dense(tar_vocab, activation='softmax')
decoder_softmax_outputs = decoder_softmax_layer(decoder_concat_input)

# 모델 정의
model = Model([encoder_inputs, decoder_inputs], decoder_softmax_outputs)
model.summary()

model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy')
es = EarlyStopping(monitor='val_loss', patience=2, verbose=1)
history = model.fit(x=[encoder_input_train, decoder_input_train], y=decoder_target_train, \
          validation_data=([encoder_input_test, decoder_input_test], decoder_target_test), \
          batch_size=256, callbacks=[es], epochs=50)

plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()
# Out:
# Model: "model_13"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_23 (InputLayer)          [(None, 60)]         0           []
#
#  embedding_10 (Embedding)       (None, 60, 256)      2048000     ['input_23[0][0]']
#
#  lstm_20 (LSTM)                 [(None, 60, 512),    1574912     ['embedding_10[0][0]']
#                                  (None, 512),
#                                  (None, 512)]
#
#  input_24 (InputLayer)          [(None, None)]       0           []
#
#  lstm_21 (LSTM)                 [(None, 60, 512),    2099200     ['lstm_20[0][0]']
#                                  (None, 512),
#                                  (None, 512)]
#
#  embedding_11 (Embedding)       (None, None, 256)    512000      ['input_24[0][0]']
#
#  lstm_22 (LSTM)                 [(None, 60, 512),    2099200     ['lstm_21[0][0]']
#                                  (None, 512),
#                                  (None, 512)]
#
#  lstm_23 (LSTM)                 [(None, None, 512),  1574912     ['embedding_11[0][0]',
#                                  (None, 512),                     'lstm_22[0][1]',
#                                  (None, 512)]                     'lstm_22[0][2]']
#
#  attention_layer (AdditiveAtten  (None, None, 512)   512         ['lstm_23[0][0]',
#  tion)                                                            'lstm_22[0][0]']
#
#  concat_layer (Concatenate)     (None, None, 1024)   0           ['lstm_23[0][0]',
#                                                                   'attention_layer[0][0]']
#
#  dense_5 (Dense)                (None, None, 2000)   2050000     ['concat_layer[0][0]']
#
# ==================================================================================================
# Total params: 11,958,736
# Trainable params: 11,958,736
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/50
# 308/308 [==============================] - 63s 182ms/step - loss: 1.7257 - val_loss: 1.6555
# Epoch 2/50
# 308/308 [==============================] - 55s 177ms/step - loss: 1.4982 - val_loss: 1.4539
# Epoch 3/50
# 308/308 [==============================] - 55s 177ms/step - loss: 1.3958 - val_loss: 1.3768
# Epoch 4/50
# 308/308 [==============================] - 54s 177ms/step - loss: 1.3209 - val_loss: 1.3400
# Epoch 5/50
# 308/308 [==============================] - 55s 177ms/step - loss: 1.2650 - val_loss: 1.3120
# Epoch 6/50
# 308/308 [==============================] - 54s 177ms/step - loss: 1.2164 - val_loss: 1.2921
# Epoch 7/50
# 308/308 [==============================] - 54s 177ms/step - loss: 1.1731 - val_loss: 1.2862
# Epoch 8/50
# 308/308 [==============================] - 54s 177ms/step - loss: 1.1334 - val_loss: 1.2787
# Epoch 9/50
# 308/308 [==============================] - 54s 177ms/step - loss: 1.0950 - val_loss: 1.2765
# Epoch 10/50
# 308/308 [==============================] - 55s 177ms/step - loss: 1.0579 - val_loss: 1.2797
# Epoch 11/50
# 308/308 [==============================] - 54s 177ms/step - loss: 1.0223 - val_loss: 1.2843
# Epoch 11: early stopping

# %%
src_index_to_word = src_tokenizer.index_word # 원문 단어 집합에서 정수 -> 단어를 얻음
tar_word_to_index = tar_tokenizer.word_index # 요약 단어 집합에서 단어 -> 정수를 얻음
tar_index_to_word = tar_tokenizer.index_word # 요약 단어 집합에서 정수 -> 단어를 얻음

# 인코더 설계
encoder_model = Model(inputs=encoder_inputs, outputs=[encoder_outputs, state_h, state_c])

# 이전 시점의 상태들을 저장하는 텐서
decoder_state_input_h = Input(shape=(hidden_size,))
decoder_state_input_c = Input(shape=(hidden_size,))

dec_emb2 = dec_emb_layer(decoder_inputs)

# 문장의 다음 단어를 예측하기 위해서 초기 상태(initial_state)를 이전 시점의 상태로 사용. 이는 뒤의 함수 decode_sequence()에 구현
# 훈련 과정에서와 달리 LSTM의 리턴하는 은닉 상태와 셀 상태인 state_h와 state_c를 버리지 않음.
decoder_outputs2, state_h2, state_c2 = decoder_lstm(dec_emb2, initial_state=[decoder_state_input_h, decoder_state_input_c])

# 어텐션 함수
decoder_hidden_state_input = Input(shape=(text_max_len, hidden_size))
attn_out_inf = attn_layer([decoder_outputs2, decoder_hidden_state_input])
decoder_inf_concat = Concatenate(axis=-1, name='concat')([decoder_outputs2, attn_out_inf])

# 디코더의 출력층
decoder_outputs2 = decoder_softmax_layer(decoder_inf_concat) 

# 최종 디코더 모델
decoder_model = Model(
    [decoder_inputs] + [decoder_hidden_state_input,decoder_state_input_h, decoder_state_input_c],
    [decoder_outputs2] + [state_h2, state_c2])

# %%
for i in range(50, 100):
    print("원문 :", seq2text(encoder_input_test[i]))
    print("실제 요약 :", seq2summary(decoder_input_test[i]))
    print("예측 요약 :", decode_sequence(encoder_input_test[i].reshape(1, text_max_len)))
    print("\n")
# Out:
# 원문 : via suspension cable delivering water aerial water filled yamuna dropped site
# 실제 요약 : air force help fight the over hour delhi fire
# 예측 요약 :  water to clean water
#
#
# 원문 : slammed congress banning cow slaughter tenure kerala remarks come amid crackdown illegal slaughterhouses several bjp ruled states
# 실제 요약 : candidate good if elected
# 예측 요약 :  in violence
#
#
# 원문 : defeating bjp candidate singh margin votes meanwhile state congress president sachin pilot took oath deputy chief minister
# 실제 요약 : rajasthan cm sachin pilot as deputy cm
# 예측 요약 :  seat in tripura assembly polls
#
#
# 원문 : world counsel said dera sacha sauda properties attached leaving client position pay court however dismissed plea directed pay within days
# 실제 요약 : fine have world ram rahim to hc
# 예측 요약 :  in jail term
#
#
# 원문 : actress said girls body experienced life nnnn
# 실제 요약 : actress on body
# 예측 요약 :  in
#
#
# 원문 : several tata group firms denying allegations tata sons said due processes followed relation removal court noted statements made extraordinary general meeting notices nature
# 실제 요약 : in defamation case
# 예측 요약 :  in deal with tata
#
#
# 원문 : sushant talked instead heading stanford university received offer dropped college went mumbai started working background dancer
# 실제 요약 : my dad tells me sushant
# 예측 요약 :  in delhi
#
#
# 원문 : home minister likely bilateral meetings ministers member states official statement stated notably member countries include china pakistan russia among others
# 실제 요약 : to attend meet in
# 예측 요약 :  to hold elections
#
#
# 원문 : venture tata sons india obtained normal channels cbi alleged airasia government officials change rules get overseas flying rights
# 실제 요약 : done without payments
# 예측 요약 :  in india bank
#
#
# 원문 : machine police recovered fake currency nearly lakh house raid part anti money laundering drive
# 실제 요약 : leader arrested for fake currency
# 예측 요약 :  notes worth lakh seized
#
#
# 원문 : aditya stopped airport since luggage cabin limit aditya seen threatening airline staff saying nahi naam aditya narayan
# 실제 요약 : airlines staff
# 예측 요약 :  to flight
#
#
# 원문 : calling biggest haul year man flying singapore reportedly hidden bars worth crore kept legs
# 실제 요약 : with gold bars in desh
# 예측 요약 :  in delhi
#
#
# 원문 : england july kohli reportedly test afghanistan june third indian play county season cheteshwar pujara ishant sharma
# 실제 요약 : to make debut before england tour
# 예측 요약 :  to play in test cricket
#
#
# 원문 : privacy counsel peter said google invested human years thousands products added said take full week send notices updated privacy policy worldwide
# 실제 요약 : to with new eu rules
# 예측 요약 :  data of
#
#
# 원문 : generate power body movements like fingers throat team claims electricity generated six could charge laptop mobile phone
# 실제 요약 : from
# 예측 요약 :  in
#
#
# 원문 : tillerson unaware reason meanwhile trump admitted tillerson things praising state secretary mike pompeo tremendous energy trump said always pompeo
# 실제 요약 : state dept official
# 예측 요약 :  us to trump
#
#
# 원문 : mla pratap reportedly attacked bjp mla belt speaker suspended rest session congress mlas staged walk protest
# 실제 요약 : mlas each other inside gujarat assembly
# 예측 요약 :  in delhi assembly
#
#
# 원문 : animal rights talking film saif earlier said project till date fight two brothers
# 실제 요약 : khan pics from sets of online
# 예측 요약 :  in film report
#
#
# 원문 : holy book khattar added books bought company price comes state government criticised move
# 실제 요약 : know its value on for
# 예측 요약 :  to be in
#
#
# 원문 : mechanism device take longer seconds identify currently printing based identification marks help challenged currency
# 실제 요약 : to help notes
# 예측 요약 :  for
#
#
# 원문 : second placed madrid sunday win barcelona points table eight point gap ahead second placed madrid messi third free kick week sixth overall season
# 실제 요약 : goal helps bar beat go clear
# 예측 요약 :  to win top in matches
#
#
# 원문 : challenging love sanjay added period drama set mughal era story war love
# 실제 요약 : on being to films
# 예측 요약 :  in bollywood
#
#
# 원문 : indian captain wicket keeper ms dhoni got really good game sense well way sort another adam gilchrist ponting added year old indian wicket keeper
# 실제 요약 : make lot more test than ms dhoni
# 예측 요약 :  to win vs pak
#
#
# 원문 : drug lord run five times added people killed philippines war drugs since duterte became president
# 실제 요약 : drugs war will not justice
# 예측 요약 :  philippine prez
#
#
# 원문 : suicide attack claimed islamic state militant group security forces area investigations underway reports added
# 실제 요약 : in pak suicide attack by isis
# 예측 요약 :  in attack
#
#
# 원문 : icici bank axis bank range functions include bill collection letters credit opening accounts trade use blockchain technology expected reduce risk fraud loc transactions
# 실제 요약 : up based trade network with banks
# 예측 요약 :  banks to stop bad loans
#
#
# 원문 : body found dumped puducherry lake taken government hospital police complaint registered matter probe underway
# 실제 요약 : head into tn police
# 예측 요약 :  for hospital
#
#
# 원문 : win five consecutive losses tournament yuvraj singh scored ball hyderabad anderson ball towards end innings helped delhi win balls spare
# 실제 요약 : hyderabad to register first win after
# 예측 요약 :  to win in ipl
#
#
# 원문 : state also announced lakh deceased injured modi assured possible help assistance centre situation
# 실제 요약 : announces crore for flood hit gujarat
# 예측 요약 :  in bihar
#
#
# 원문 : final kg category year old mother three currently tied taylor ireland five gold medals world championships
# 실제 요약 : medal after
# 예측 요약 :  to win gold at cwg
#
#
# 원문 : restoration company statue note dating back popular economic situation political religious matters famous people among
# 실제 요약 : note found inside statue in spain
# 예측 요약 :  girls from
#
#
# 원문 : loans banks terming loan waiver misleading added political stunt congress solution farmers said
# 실제 요약 : not of farmers pm modi
# 예측 요약 :  to be in india
#
#
# 원문 : report confirmed suspected someone else made signature accused train late reached meerut examination officials said
# 실제 요약 : sign does not match
# 예측 요약 :  in delhi metro station
#
#
# 원문 : great support people iran appropriate time respect people iran try take back corrupt government trump tweeted earlier trump called iranian regime
# 실제 요약 : at time trump
# 예측 요약 :  iran to trump
#
#
# 원문 : residents health important profits court asked authorities look fire safety dealing unauthorised
# 실제 요약 : of illegal in delhi sc
# 예측 요약 :  in delhi
#
#
# 원문 : girl holding featured raj kapoor film naam amul official twitter handle sharing poster wrote amul precious lost rk studios fire
# 실제 요약 : on fire at
# 예측 요약 :  in bollywood
#
#
# 원문 : pakistan said pakistan needed nine runs win six balls nehra ran towards ganguly said main aap main match win
# 실제 요약 : ganguly in odi against pak
# 예측 요약 :  to play in cricket
#
#
# 원문 : nasa satellite television experiment launched bringing cable television rural india padma awardee passed away december
# 실제 요약 : had tv to india
# 예측 요약 :  space for st time
#
#
# 원문 : department led gujarat energy minister saurabh patel working creating policy provide required infrastructure mass run electric vehicles patel said stations charged batteries available manner similar existing petrol pumps
# 실제 요약 : asks ola uber to start electric taxi services
# 예측 요약 :  in india
#
#
# 원문 : final sunday reacting spectators federer said guys make nervous guys make practice guys fill federer father also began crying standing crowd
# 실제 요약 : down after winning record th grand slam
# 예측 요약 :  serena on serena
#
#
# 원문 : banks collectively lost nearly crore cyber frauds less total money lost frauds cyber frauds constituted almost one third banking frauds
# 실제 요약 : in fy rbi
# 예측 요약 :  banks to banks
#
#
# 원문 : said added nda government need five years fulfil promises
# 실제 요약 : not in good state as am not fm bjp mp swamy
# 예측 요약 :  pm modi on nda
#
#
# 원문 : cockpit two flights last year pilot bought full tickets also ordered pay wife journey
# 실제 요약 : suspended fined lakh for wife in
# 예측 요약 :  to for flight
#
#
# 원문 : kashmir militant heard saying people considered families contest elections burden families life
# 실제 요약 : poll candidates in
# 예측 요약 :  polls
#
#
# 원문 : put picture almost twin cousin arjun kapoor wrote alongside photo sonam father anil kapoor younger brother arjun father boney kapoor film producer
# 실제 요약 : shares pic with arjun kapoor
# 예측 요약 :  to srk on his birthday
#
#
# 원문 : comes cm vasundhara raje called late night meeting senior ministers bureaucrats per reports government might provisions bill prompted several protests
# 실제 요약 : to review bill public from probe
# 예측 요약 :  centre to centre
#
#
# 원문 : reports rebel pdp mlas touch bjp bjp june ended alliance pdp following mufti resigned cm governor rule imposed
# 실제 요약 : results if delhi tries to break
# 예측 요약 :  in tripura assembly polls
#
#
# 원문 : journalists broke official secrets act added said people read judgment
# 실제 요약 : do with press freedom
# 예측 요약 :  to kill me
#
#
# 원문 : basic services including pick delivery cash cheque books provided rbi said cases banks senior citizens differently abled persons banking facilities branches reported
# 실제 요약 : above by dec rbi
# 예측 요약 :  banks to govt
#
#
# 원문 : vehicle protesters around people killed others injured since began april
# 실제 요약 : vehicle into
# 예측 요약 :  in

# %% [markdown]
# ## 결과
#
# - 임베딩 차원과 히든 사이즈를 조절해봤는데... 여전히 요약문이 바보같았다.

# %% [markdown]
# ## 회고
#
# - 아직 attention, rnn, lstm 등을 잘 이해하지 못해서 모델을 변형해서 요약문을 더 잘 뽑아 내는 것은 하지 못하였다.
#
# - 입력 텍스트를 임베딩하는 과정에서 랜덤셔플이 들어가서 같은 문장에 대한 추상적요약과 추출적요약을 하지 못한 점이 아쉽다. 벡터화 하기전까지의 텍스트와 찾고자 하는 실제 요약문을 for문 안에서 비교하려고 하였으나 같은 문장이 for문을 돌려도 나오지 않았다. 아직 정확하게 프로세스에 대해서 이해하지 못해서 그런지 생각에 빠진 점을 찾지 못했다.
#
# - 전처리과정은 하고자 하는 작업에 따라서 신중하게 선택되어야 하는 것을 알게 되었다. 예제에서 복사 붙여넣기로 단어수를 자르기만 하면 하고자 하는 요약이 제대로 되지 않는다.
